# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Iris dataset (built-in)
from google.colab import files
uploaded = files.upload()

iris = pd.read_csv("Iris.csv")   # use your file name

# Upload Adult dataset manually
from google.colab import files
uploaded = files.upload()

# Read uploaded file
adult = pd.read_csv("adult_dataset.csv")

# Preview datasets
print("Adult Dataset:")
print(adult.head())

print("\nIris Dataset:")
print(iris.head())
# Out:
#      <input type="file" id="files-d474c08e-19a5-4c96-aaf6-fb022d3aedd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d474c08e-19a5-4c96-aaf6-fb022d3aedd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure()
plt.hist(adult['age'], bins=20)
plt.title("Age Distribution (Adult Dataset)")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

plt.figure()
sns.histplot(iris['SepalLengthCm'], kde=True)
plt.title("Sepal Length Distribution (Iris)")
plt.xlabel("Sepal Length")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal vs Petal Length")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(
    iris['SepalLengthCm'],
    iris['PetalLengthCm'],
    iris['PetalWidthCm']
)

ax.set_xlabel("Sepal Length")
ax.set_ylabel("Petal Length")
ax.set_zlabel("Petal Width")

plt.title("3D Iris Visualization")
plt.show()

# %%
# Simulated example (Adult dataset doesn't have time)
adult['age_group'] = pd.cut(adult['age'], bins=10)

age_counts = adult['age_group'].value_counts().sort_index()

plt.figure()
age_counts.plot()
plt.title("Age Group Trend")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %%
sns.pairplot(iris, hue="Species")
plt.show()

# %%
# !pip install squarify
import squarify

# Count categories
data = adult['workclass'].value_counts()

plt.figure()
squarify.plot(sizes=data.values, label=data.index)
plt.title("Workclass Distribution (Treemap)")
plt.axis('off')
plt.show()

# %%
import networkx as nx

G = nx.Graph()

# Example relationships
G.add_edge("Private", ">50K")
G.add_edge("Self-emp", "<=50K")

nx.draw(G, with_labels=True)
plt.title("Network Graph Example")
plt.show()
